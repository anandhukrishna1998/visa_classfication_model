# %%
import pandas as pd
from evidently.dashboard import Dashboard
from evidently.tabs import DataDriftTab, CatTargetDriftTab
from evidently.model_profile import Profile
from evidently.profile_sections import DataDriftProfileSection
# Out:
# c:\Users\anand\Anaconda3\envs\visa\lib\site-packages\evidently\analyzers\__init__.py:3: UserWarning: analyzers are deprecated, use metrics instead
#   warnings.warn("analyzers are deprecated, use metrics instead")
# c:\Users\anand\Anaconda3\envs\visa\lib\site-packages\evidently\dashboard\__init__.py:8: UserWarning: dashboards are deprecated, use metrics instead
#   warnings.warn("dashboards are deprecated, use metrics instead")
# c:\Users\anand\Anaconda3\envs\visa\lib\site-packages\evidently\tabs\__init__.py:8: UserWarning: 'import evidently.tabs' is deprecated, use 'import evidently.dashboard.tabs'
#   warnings.warn(
# c:\Users\anand\Anaconda3\envs\visa\lib\site-packages\evidently\model_profile\__init__.py:8: UserWarning: model profiles are deprecated, use metrics instead
#   warnings.warn("model profiles are deprecated, use metrics instead")
# c:\Users\anand\Anaconda3\envs\visa\lib\site-packages\evidently\profile_sections\__init__.py:8: UserWarning: 'import evidently.profile_sections' is deprecated, use 'import evidently.model_profile.sections'
#   warnings.warn(

# %%
visa_df = pd.read_csv("EasyVisa.csv")

# %%
#Data drift dashboard

# %%
visa_df.shape
# Out:
# (25480, 12)

# %%
visa_df[:17836]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 17831  EZYV17832    Europe            Bachelor's                  N
# 17832  EZYV17833    Europe             Doctorate                  Y
# 17833  EZYV17834      Asia            Bachelor's                  N
# 17834  EZYV17835      Asia            Bachelor's                  N
# 17835  EZYV17836      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 17831                     N            29765         2005
# 17832                     N           111687         2009
# 17833                     Y             2160         1992
# 17834                     N             1900         1986
# 17835                     N             1178         2001
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 17831            Northeast       18685.7300         Year                  Y
# 17832                 West       36956.3600         Year                  Y
# 17833                South       11277.1300         Year                  Y
# 17834                South       39247.4100         Year                  Y
# 17835                 West       50175.0100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 17831   Certified
# 17832   Certified
# 17833   Certified
# 17834   Certified
# 17835      Denied
#
# [17836 rows x 12 columns]

# %%
visa_df[17836:]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 17836  EZYV17837      Asia              Master's                  Y
# 17837  EZYV17838    Europe           High School                  Y
# 17838  EZYV17839      Asia              Master's                  Y
# 17839  EZYV17840      Asia            Bachelor's                  N
# 17840  EZYV17841      Asia            Bachelor's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 17836                     N              447         2004
# 17837                     N             1514         1999
# 17838                     N             3891         2000
# 17839                     N             3096         2008
# 17840                     N             1301         2006
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 17836                South         56467.61         Year                  Y
# 17837            Northeast        106829.01         Year                  Y
# 17838              Midwest        151194.24         Year                  Y
# 17839              Midwest         75250.34         Year                  Y
# 17840                South         43126.86         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South         77092.57         Year                  Y
# 25476            Northeast        279174.79         Year                  Y
# 25477                South        146298.85         Year                  N
# 25478                 West         86154.77         Year                  Y
# 25479              Midwest         70876.91         Year                  Y
#
#       case_status
# 17836   Certified
# 17837   Certified
# 17838   Certified
# 17839   Certified
# 17840   Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [7644 rows x 12 columns]

# %%
visa_data_drift_dashboard = Dashboard(tabs=[DataDriftTab()])

# %%
visa_data_drift_dashboard.calculate(visa_df[:20000], visa_df[20000:])

# %%
visa_data_drift_dashboard.save("visa_data_drift_report.html")
